# %%
# WithOUT Unique Id

import random
import csv
import json

import random
import time
    
def str_time_prop(start, end, time_format, prop):
    stime = time.mktime(time.strptime(start, time_format))
    etime = time.mktime(time.strptime(end, time_format))

    ptime = stime + prop * (etime - stime)

    return time.strftime(time_format, time.localtime(ptime))


def random_date(start, end, prop):
    return str_time_prop(start, end, '%d-%m-%Y', prop)
    
#print(random_date("1-1-2000", "1-1-2022", random.random()))

# Define the number of rows and columns in each table
num_rows = 15000000# 15 million rows per table
num_cols = 5


# Define the column headers
headers = ["WORKER_ID", "FIRST_NAME", "LAST_NAME", "SALARY", "JOINING_DATE", "DEPARTMENT"]

# Define some lists of random data
FIRST_NAME = ["Alice", "Bob", "Charlie", "Dave", "Eve", "Frank", "Grace", "Heidi", "Ivy", "Jack"]
SALARY = [random.randint(1500, 20000) for _ in range(100)]
JOINING_DATE = [random_date("1-1-2000", "1-1-2022", random.random()) for _ in range(100)]
DEPARTMENT = ["HR", "Admin", "Account", "IT", "Graphics"]
LAST_NAME = ["Arora","Verma","Singhal", "Singh", "Bhati", "Diwan", "Kumar", "Chauhan"]

# Generate the data for each table and write it to a separate CSV and JSON file
for i in range(3):
    # Generate the data for this table
    data = []

    for j in range(num_rows):
        WORKER_ID = j*10+i
        row = [WORKER_ID, random.choice(FIRST_NAME), random.choice(LAST_NAME), random.choice(SALARY), random.choice(JOINING_DATE), random.choice(DEPARTMENT)]
        data.append(row)
      
    # Write the data to a JSON file
    #json_filename = f"person_data_table_{i+1}.json"
    #with open(json_filename, "w") as jsonfile:
    #    json.dump(data, jsonfile)

    # Add the column headers to the data
    data.insert(0, headers) 
    
    # Write the data to a CSV file
    csv_filename = f"person_data_table_{i+1}.csv"
    with open(csv_filename, "w", newline="") as csvfile:
        writer = csv.writer(csvfile)
        writer.writerows(data)

# %% [markdown]
# 2nd Table

# %%
# WithOUT Unique Id

import random
import csv
import json

import random
import time
    
def str_time_prop(start, end, time_format, prop):
    stime = time.mktime(time.strptime(start, time_format))
    etime = time.mktime(time.strptime(end, time_format))

    ptime = stime + prop * (etime - stime)

    return time.strftime(time_format, time.localtime(ptime))


def random_date(start, end, prop):
    return str_time_prop(start, end, '%d-%m-%Y', prop)
    
#print(random_date("1-1-2000", "1-1-2022", random.random()))

# Define the number of rows and columns in each table
# 1 million rows per table
num_cols = 6
bonus_rows = 1500000

# Define the column headers
headers = ["WORKER_REF_ID", "BONUS_AMOUNT", "BONUS_DATE"]
# Define some lists of random data
BONUS_AMOUNT = [random.randint(500, 10000) for _ in range(100)]
BONUS_DATE = [random_date("1-1-2000", "1-1-2022", random.random()) for _ in range(100)]

# Generate the data for each table and write it to a separate CSV and JSON file
for i in range(3):
    # Generate the data for this table
    data = []

    for j in range(bonus_rows):
        WORKER_REF_ID = j*10+i 
        row = [WORKER_REF_ID, random.choice(BONUS_AMOUNT), random.choice(BONUS_DATE)]
        data.append(row)
      
    # Write the data to a JSON file
    #json_filename = f"bonus_{i+1}.json"
    #with open(json_filename, "w") as jsonfile:
    #    json.dump(data, jsonfile)

    # Add the column headers to the data
    data.insert(0, headers) 
    
    # Write the data to a CSV file
    csv_filename = f"bonus_{i+1}.csv"
    with open(csv_filename, "w", newline="") as csvfile:
        writer = csv.writer(csvfile)
        writer.writerows(data)

# %% [markdown]
# 3rd Table

# %%
# WithOUT Unique Id

import random
import csv
import json

import random
import time
    
def str_time_prop(start, end, time_format, prop):
    stime = time.mktime(time.strptime(start, time_format))
    etime = time.mktime(time.strptime(end, time_format))

    ptime = stime + prop * (etime - stime)

    return time.strftime(time_format, time.localtime(ptime))


def random_date(start, end, prop):
    return str_time_prop(start, end, '%d-%m-%Y', prop)
    
#print(random_date("1-1-2000", "1-1-2022", random.random()))

# Define the number of rows and columns in each table
num_rows = 15000000# 10 million rows per table
num_cols = 3


# Define the column headers
headers = ["WORKER_REF_ID", "WORKER_TITLE", "AFFECTED_FROM"]

# Define some lists of random data
AFFECTED_FROM = [random_date("1-1-2000", "1-1-2022", random.random()) for _ in range(100)]
WORKER_TITLE = ["Manager", "Executive", "Asst. Manager", "Lead"]

# Generate the data for each table and write it to a separate CSV and JSON file
for i in range(3):
    # Generate the data for this table
    data = []

    for j in range(num_rows):
        WORKER_REF_ID = j*10+i
        row = [WORKER_REF_ID, random.choice(WORKER_TITLE), random.choice(AFFECTED_FROM)]
        data.append(row)
      
    # Write the data to a JSON file
    #json_filename = f"title_{i+1}.json"
    #with open(json_filename, "w") as jsonfile:
    #    json.dump(data, jsonfile)

    # Add the column headers to the data
    data.insert(0, headers) 
    
    # Write the data to a CSV file
    csv_filename = f"title_{i+1}.csv"
    with open(csv_filename, "w", newline="") as csvfile:
        writer = csv.writer(csvfile)
        writer.writerows(data)
